# %%
#!pip install pandas
#!pip install openpyxl

# %%
import pandas as pd

# %%
# Define the file path
file_path = 'WorkFlow.xlsx'

# Read the Excel file into a pandas DataFrame
data = pd.read_excel(file_path)

data
# Out:
#                                                Task     Status
# 0                                Created Repository  Completed
# 1          ReadMe, License, Helper text, Git Ignore  Completed
# 2     Algorithms specification, data provider ipynb  Completed
# 3   DataSet, Creation of excelsheet for supervision  Completed
# 4              Created Backup datasheet on zip file  Completed
# 5      Data analyst of assignment 2 for supervision  Completed
# 6      Data analyst of assignment 1 for supervision  Completed
# 7            Implementation on pandas to parse data  Completed
# 8                Recreate dataset with only numbers  Completed
# 9                            Train/ Test Data phase  Completed
# 10     Data analyst of assignment 3 for supervision  Completed
# 11            Loggicstic regression, Decisison tree  Completed
# 12                                      Perceptron   Completed
# 13                          Neural Network Training  Completed
# 14                               Abstract For paper  Completed
# 15                            Learning for xG boost  Completed
# 16                                   New Modelling   Completed
# 17                                  Data optimizing  Completed
# 18                 Web Development and model saving  Completed
# 19                        Train on more assignments    Running
