# %%
import pandas as pd
import numpy as np
import json
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import string
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense
from imblearn.over_sampling import SMOTE
from tensorflow import keras

# %%
x_src_path = '../Dataset/text_assignment1.json'
y_src_path = '../DataBook/Assignment1_Data_Analyst.xlsx'

# %%
data = pd.read_json(x_src_path)

# %%
df_supervision = pd.read_excel(y_src_path)
plagiarised_array = df_supervision['Plagiarised'].astype(int).values

# %%
texts = data.iloc[:, :].astype(str).values.tolist()

texts = [[element if element != 'None' else '' for element in sublist] for sublist in texts]

# %%
tokenizer = Tokenizer(num_words=10000, oov_token="<OOV>") 
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)

max_sequence_len = max([len(seq) for seq in sequences])
data_vectorized = pad_sequences(sequences, maxlen=max_sequence_len)

# %%
X = data_vectorized
y = plagiarised_array
# ros = SMOTE()
# X_resampled, y_resampled = ros.fit_resample(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=32)
#seed 32 results 100% on test score 24

# %%
count_0 = 0
count_1 = 0

for element in y_test:
    if element == 0:
        count_0 += 1
    elif element == 1:
        count_1 += 1

print("Number of 0s:", count_0)
print("Number of 1s:", count_1)
# Out:
# Number of 0s: 13
# Number of 1s: 4

# %%
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score, classification_report
p = Perceptron()
p.fit(X_train,y_train)

print(f"Training data score: {p.score(X_train, y_train)}")
print(f"Test data score: {p.score(X_test, y_test)}")
# Out:
# Training data score: 1.0
# Test data score: 0.8823529411764706

# %%
predictions = p.predict(X_test)
for i in range(len(X_test)):
    print("Predicted:", predictions[i], "Actual:", y_test[i])
# y_pred = p.predict(X_test)

# # Calculate the accuracy of the classifier
# accuracy = accuracy_score(y_test, y_pred)

# print(classification_report(y_test, y_pred))
# Out:
# Predicted: 1 Actual: 1
# Predicted: 0 Actual: 0
# Predicted: 0 Actual: 0
# Predicted: 0 Actual: 0
# Predicted: 0 Actual: 0
# Predicted: 0 Actual: 0
# Predicted: 0 Actual: 0
# Predicted: 1 Actual: 1
# Predicted: 0 Actual: 0
# Predicted: 0 Actual: 0
# Predicted: 0 Actual: 0
# Predicted: 0 Actual: 1
# Predicted: 0 Actual: 0
# Predicted: 0 Actual: 1
# Predicted: 0 Actual: 0
# Predicted: 0 Actual: 0
# Predicted: 0 Actual: 0

# %%
modelNames = [
    '1d',
    '2d',
    '3d',
    '4d',
    '5d',
    '6d',
    '7d'
]

NODES_PER_HIDDEN_LAYER = 64

models = [ 

    keras.models.Sequential([
    keras.layers.Input(shape=(4394,)),
    keras.layers.Dense(2, activation='softmax')
]),

    keras.models.Sequential([
    keras.layers.Input(shape=(4394,)),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(2, activation='softmax')
]),

 keras.models.Sequential([
    keras.layers.Input(shape=(4394,)),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(2, activation='softmax')
]),

 keras.models.Sequential([
    keras.layers.Input(shape=(4394,)),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(2, activation='softmax')
]),

 keras.models.Sequential([
    keras.layers.Input(shape=(4394,)),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(2, activation='softmax')
]),

keras.models.Sequential([
    keras.layers.Input(shape=(4394,)),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(2, activation='softmax')
]),

keras.models.Sequential([
    keras.layers.Input(shape=(4394,)),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(2, activation='softmax')
])

]

# %%
LOSS_FN = keras.losses.sparse_categorical_crossentropy

for model in models:
    model.compile(optimizer='adam',loss=LOSS_FN,metrics=['accuracy'])

# %%
TRAINING_EPOCHS = 20

# train all models
for model, name in zip(models, modelNames):
    print(f'training model {name}')
    model.fit(X_train, y_train, epochs=TRAINING_EPOCHS)
# Out:
# training model 1d
# Epoch 1/20
# 2/2 [==============================] - 0s 4ms/step - loss: 8.5833 - accuracy: 0.7297
# Epoch 2/20
# 2/2 [==============================] - 0s 4ms/step - loss: 9.5574 - accuracy: 0.8378
# Epoch 3/20
# 2/2 [==============================] - 0s 3ms/step - loss: 6.4855 - accuracy: 0.8378
# Epoch 4/20
# 2/2 [==============================] - 0s 3ms/step - loss: 1.8544 - accuracy: 0.9189
# Epoch 5/20
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1110 - accuracy: 0.9459
# Epoch 6/20
# 2/2 [==============================] - 0s 3ms/step - loss: 1.4582 - accuracy: 0.8649
# Epoch 7/20
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1395 - accuracy: 0.9189
# Epoch 8/20
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 9/20
# 2/2 [==============================] - 0s 3ms/step - loss: 7.4280e-05 - accuracy: 1.0000
# Epoch 10/20
# 2/2 [==============================] - 0s 3ms/step - loss: 3.7242e-06 - accuracy: 1.0000
# Epoch 11/20
# 2/2 [==============================] - 0s 2ms/step - loss: 3.1252e-07 - accuracy: 1.0000
# Epoch 12/20
# 2/2 [==============================] - 0s 3ms/step - loss: 4.1884e-08 - accuracy: 1.0000
# Epoch 13/20
# 2/2 [==============================] - 0s 3ms/step - loss: 6.4437e-09 - accuracy: 1.0000
# Epoch 14/20
# 2/2 [==============================] - 0s 2ms/step - loss: 3.2219e-09 - accuracy: 1.0000
# Epoch 15/20
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 16/20
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 17/20
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 18/20
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 19/20
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 20/20
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# training model 2d
# Epoch 1/20
# 2/2 [==============================] - 0s 7ms/step - loss: 12.7721 - accuracy: 0.4595
# Epoch 2/20
# 2/2 [==============================] - 0s 6ms/step - loss: 27.6959 - accuracy: 0.8108
# Epoch 3/20
# 2/2 [==============================] - 0s 4ms/step - loss: 17.3154 - accuracy: 0.8108
# Epoch 4/20
# 2/2 [==============================] - 0s 5ms/step - loss: 5.7426 - accuracy: 0.8649
# Epoch 5/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4931 - accuracy: 0.9189
# Epoch 6/20
# 2/2 [==============================] - 0s 4ms/step - loss: 2.7393 - accuracy: 0.8378
# Epoch 7/20
# 2/2 [==============================] - 0s 4ms/step - loss: 4.3565 - accuracy: 0.7027
# Epoch 8/20
# 2/2 [==============================] - 0s 4ms/step - loss: 1.2803 - accuracy: 0.7568
# Epoch 9/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1307 - accuracy: 0.9730
# Epoch 10/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0555 - accuracy: 0.9730
# Epoch 11/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 12/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0975 - accuracy: 0.9730
# Epoch 13/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0523 - accuracy: 0.9730
# Epoch 14/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 15/20
# 2/2 [==============================] - 0s 3ms/step - loss: 1.8181e-04 - accuracy: 1.0000
# Epoch 16/20
# 2/2 [==============================] - 0s 4ms/step - loss: 1.3448e-05 - accuracy: 1.0000
# Epoch 17/20
# 2/2 [==============================] - 0s 4ms/step - loss: 1.5722e-06 - accuracy: 1.0000
# Epoch 18/20
# 2/2 [==============================] - 0s 4ms/step - loss: 2.7708e-07 - accuracy: 1.0000
# Epoch 19/20
# 2/2 [==============================] - 0s 4ms/step - loss: 7.4103e-08 - accuracy: 1.0000
# Epoch 20/20
# 2/2 [==============================] - 0s 3ms/step - loss: 2.8997e-08 - accuracy: 1.0000
# training model 3d
# Epoch 1/20
# 2/2 [==============================] - 0s 5ms/step - loss: 5.4835 - accuracy: 0.6216
# Epoch 2/20
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9109 - accuracy: 0.8108
# Epoch 3/20
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 4/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0660 - accuracy: 0.9730
# Epoch 5/20
# 2/2 [==============================] - 0s 4ms/step - loss: 5.1550e-08 - accuracy: 1.0000
# Epoch 6/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6634 - accuracy: 0.9459
# Epoch 7/20
# 2/2 [==============================] - 0s 4ms/step - loss: 1.3355e-05 - accuracy: 1.0000
# Epoch 8/20
# 2/2 [==============================] - 0s 4ms/step - loss: 3.8662e-08 - accuracy: 1.0000
# Epoch 9/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 10/20
# 2/2 [==============================] - 0s 3ms/step - loss: 6.4437e-09 - accuracy: 1.0000
# Epoch 11/20
# 2/2 [==============================] - 0s 3ms/step - loss: 5.1550e-08 - accuracy: 1.0000
# Epoch 12/20
# 2/2 [==============================] - 0s 4ms/step - loss: 9.3434e-08 - accuracy: 1.0000
# Epoch 13/20
# 2/2 [==============================] - 0s 4ms/step - loss: 2.3842e-07 - accuracy: 1.0000
# Epoch 14/20
# 2/2 [==============================] - 0s 6ms/step - loss: 5.0261e-07 - accuracy: 1.0000
# Epoch 15/20
# 2/2 [==============================] - 0s 6ms/step - loss: 9.6977e-07 - accuracy: 1.0000
# Epoch 16/20
# 2/2 [==============================] - 0s 6ms/step - loss: 1.6721e-06 - accuracy: 1.0000
# Epoch 17/20
# 2/2 [==============================] - 0s 5ms/step - loss: 2.6869e-06 - accuracy: 1.0000
# Epoch 18/20
# 2/2 [==============================] - 0s 5ms/step - loss: 4.0754e-06 - accuracy: 1.0000
# Epoch 19/20
# 2/2 [==============================] - 0s 5ms/step - loss: 5.7988e-06 - accuracy: 1.0000
# Epoch 20/20
# 2/2 [==============================] - 0s 4ms/step - loss: 8.7655e-06 - accuracy: 1.0000
# training model 4d
# Epoch 1/20
# 2/2 [==============================] - 1s 5ms/step - loss: 2.4940 - accuracy: 0.7568
# Epoch 2/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.9494 - accuracy: 0.9459
# Epoch 3/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1874 - accuracy: 0.9459
# Epoch 4/20
# 2/2 [==============================] - 0s 4ms/step - loss: 1.6220 - accuracy: 0.8378
# Epoch 5/20
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8687 - accuracy: 0.9189
# Epoch 6/20
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9875 - accuracy: 0.9459
# Epoch 7/20
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2979 - accuracy: 0.9730
# Epoch 8/20
# 2/2 [==============================] - 0s 3ms/step - loss: 1.9749e-06 - accuracy: 1.0000
# Epoch 9/20
# 2/2 [==============================] - 0s 3ms/step - loss: 6.4437e-08 - accuracy: 1.0000
# Epoch 10/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 11/20
# 2/2 [==============================] - 0s 4ms/step - loss: 1.0264e-05 - accuracy: 1.0000
# Epoch 12/20
# 2/2 [==============================] - 0s 3ms/step - loss: 6.2429e-04 - accuracy: 1.0000
# Epoch 13/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 14/20
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 15/20
# 2/2 [==============================] - 0s 4ms/step - loss: 4.8239e-05 - accuracy: 1.0000
# Epoch 16/20
# 2/2 [==============================] - 0s 4ms/step - loss: 2.8931e-06 - accuracy: 1.0000
# Epoch 17/20
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2875e-07 - accuracy: 1.0000
# Epoch 18/20
# 2/2 [==============================] - 0s 4ms/step - loss: 3.2219e-08 - accuracy: 1.0000
# Epoch 19/20
# 2/2 [==============================] - 0s 4ms/step - loss: 9.6656e-09 - accuracy: 1.0000
# Epoch 20/20
# 2/2 [==============================] - 0s 4ms/step - loss: 3.2219e-09 - accuracy: 1.0000
# training model 5d
# Epoch 1/20
# 2/2 [==============================] - 1s 6ms/step - loss: 1.9177 - accuracy: 0.5676
# Epoch 2/20
# 2/2 [==============================] - 0s 5ms/step - loss: 1.7824 - accuracy: 0.8108
# Epoch 3/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3335 - accuracy: 0.8919
# Epoch 4/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2116 - accuracy: 0.8919
# Epoch 5/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2304 - accuracy: 0.9730
# Epoch 6/20
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0618 - accuracy: 0.9730
# Epoch 7/20
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3289 - accuracy: 0.8378
# Epoch 8/20
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 9/20
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 10/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0326 - accuracy: 0.9730
# Epoch 11/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 12/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 13/20
# 2/2 [==============================] - 0s 3ms/step - loss: 1.6213e-04 - accuracy: 1.0000
# Epoch 14/20
# 2/2 [==============================] - 0s 4ms/step - loss: 1.1214e-04 - accuracy: 1.0000
# Epoch 15/20
# 2/2 [==============================] - 0s 3ms/step - loss: 1.7150e-04 - accuracy: 1.0000
# Epoch 16/20
# 2/2 [==============================] - 0s 3ms/step - loss: 3.6938e-04 - accuracy: 1.0000
# Epoch 17/20
# 2/2 [==============================] - 0s 4ms/step - loss: 5.9299e-04 - accuracy: 1.0000
# Epoch 18/20
# 2/2 [==============================] - 0s 4ms/step - loss: 8.1392e-04 - accuracy: 1.0000
# Epoch 19/20
# 2/2 [==============================] - 0s 3ms/step - loss: 9.6227e-04 - accuracy: 1.0000
# Epoch 20/20
# 2/2 [==============================] - 0s 4ms/step - loss: 9.2396e-04 - accuracy: 1.0000
# training model 6d
# Epoch 1/20
# 2/2 [==============================] - 1s 6ms/step - loss: 1.0668 - accuracy: 0.8108
# Epoch 2/20
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6448 - accuracy: 0.8378
# Epoch 3/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3255 - accuracy: 0.8649
# Epoch 4/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1457 - accuracy: 0.9730
# Epoch 5/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3840 - accuracy: 0.8649
# Epoch 6/20
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0319 - accuracy: 0.9730
# Epoch 7/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1627 - accuracy: 0.8919
# Epoch 8/20
# 2/2 [==============================] - 0s 14ms/step - loss: 7.3304e-04 - accuracy: 1.0000
# Epoch 9/20
# 2/2 [==============================] - 0s 6ms/step - loss: 6.2844e-04 - accuracy: 1.0000
# Epoch 10/20
# 2/2 [==============================] - 0s 6ms/step - loss: 8.8524e-04 - accuracy: 1.0000
# Epoch 11/20
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 12/20
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 13/20
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 14/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 15/20
# 2/2 [==============================] - 0s 4ms/step - loss: 5.5114e-04 - accuracy: 1.0000
# Epoch 16/20
# 2/2 [==============================] - 0s 4ms/step - loss: 3.1850e-04 - accuracy: 1.0000
# Epoch 17/20
# 2/2 [==============================] - 0s 4ms/step - loss: 1.8013e-04 - accuracy: 1.0000
# Epoch 18/20
# 2/2 [==============================] - 0s 4ms/step - loss: 1.0754e-04 - accuracy: 1.0000
# Epoch 19/20
# 2/2 [==============================] - 0s 4ms/step - loss: 7.5829e-05 - accuracy: 1.0000
# Epoch 20/20
# 2/2 [==============================] - 0s 4ms/step - loss: 5.2345e-05 - accuracy: 1.0000
# training model 7d
# Epoch 1/20
# 2/2 [==============================] - 1s 6ms/step - loss: 0.8910 - accuracy: 0.6216
# Epoch 2/20
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8035 - accuracy: 0.8108
# Epoch 3/20
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2572 - accuracy: 0.8649
# Epoch 4/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1018 - accuracy: 0.9730
# Epoch 5/20
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0993 - accuracy: 0.9730
# Epoch 6/20
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 7/20
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0665 - accuracy: 0.9730
# Epoch 8/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 9/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 10/20
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 11/20
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 12/20
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 13/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 14/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 15/20
# 2/2 [==============================] - 0s 4ms/step - loss: 4.7869e-04 - accuracy: 1.0000
# Epoch 16/20
# 2/2 [==============================] - 0s 4ms/step - loss: 2.7870e-04 - accuracy: 1.0000
# Epoch 17/20
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0664e-04 - accuracy: 1.0000
# Epoch 18/20
# 2/2 [==============================] - 0s 4ms/step - loss: 1.3235e-04 - accuracy: 1.0000
# Epoch 19/20
# 2/2 [==============================] - 0s 4ms/step - loss: 8.4159e-05 - accuracy: 1.0000
# Epoch 20/20
# 2/2 [==============================] - 0s 4ms/step - loss: 6.8824e-05 - accuracy: 1.0000

# %%
# get all model accuracy scores on test data
scores = [model.evaluate(X_test,y_test)[1] for model in models]
# Out:
# 1/1 [==============================] - 0s 95ms/step - loss: 5.5624 - accuracy: 0.8824
# 1/1 [==============================] - 0s 85ms/step - loss: 10.6710 - accuracy: 0.8235
# 1/1 [==============================] - 0s 94ms/step - loss: 7.2980 - accuracy: 0.7647
# 1/1 [==============================] - 0s 110ms/step - loss: 1.9453 - accuracy: 0.8824
# 1/1 [==============================] - 0s 97ms/step - loss: 1.5977 - accuracy: 0.8235
# 1/1 [==============================] - 0s 105ms/step - loss: 3.9472 - accuracy: 0.8235
# 1/1 [==============================] - 0s 104ms/step - loss: 1.1460 - accuracy: 0.8824

# %%
import matplotlib.pyplot as plt
modelNames.insert(0, 'perceptron')
scores.insert(0, p.score(X_test, y_test) )

plt.bar(modelNames,scores)
plt.ylim(0.75, 1.0)
plt.ylabel('Test Accuracy (%)') 
plt.xlabel(str(NODES_PER_HIDDEN_LAYER) + " nodes per hidden layer")
plt.show()
