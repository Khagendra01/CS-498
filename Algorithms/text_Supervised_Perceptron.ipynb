# %%
import pandas as pd
import numpy as np
import json
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import string
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense
from imblearn.over_sampling import SMOTE
from tensorflow import keras

# %%
x_src_path = '../Dataset/text_assignment1.json'
y_src_path = '../DataBook/Assignment1_Data_Analyst.xlsx'

# %%
data = pd.read_json(x_src_path)

# %%
df_supervision = pd.read_excel(y_src_path)
plagiarised_array = df_supervision['Plagiarised'].astype(int).values

# %%
texts = data.iloc[:, :].astype(str).values.tolist()

# %%
tokenizer = Tokenizer(num_words=10000) 
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)

max_sequence_len = max([len(seq) for seq in sequences])
data_vectorized = pad_sequences(sequences, maxlen=max_sequence_len)

# %%
X = data_vectorized
y = plagiarised_array
ros = SMOTE()
X_resampled, y_resampled = ros.fit_resample(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.3, random_state=3)
#seed 32 results 100% on test score 24

# %%
count_0 = 0
count_1 = 0

for element in y_test:
    if element == 0:
        count_0 += 1
    elif element == 1:
        count_1 += 1

print("Number of 0s:", count_0)
print("Number of 1s:", count_1)
# Out:
# Number of 0s: 11
# Number of 1s: 15

# %%
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score, classification_report
p = Perceptron()
p.fit(X_train,y_train)

print(f"Training data score: {p.score(X_train, y_train)}")
print(f"Test data score: {p.score(X_test, y_test)}")
# Out:
# Training data score: 1.0
# Test data score: 1.0

# %%
predictions = p.predict(X_test)
for i in range(len(X_test)):
    print("Predicted:", predictions[i], "Actual:", y_test[i])
# y_pred = p.predict(X_test)

# # Calculate the accuracy of the classifier
# accuracy = accuracy_score(y_test, y_pred)

# print(classification_report(y_test, y_pred))
# Out:
# Predicted: 1 Actual: 1
# Predicted: 1 Actual: 1
# Predicted: 0 Actual: 0
# Predicted: 1 Actual: 1
# Predicted: 1 Actual: 1
# Predicted: 1 Actual: 1
# Predicted: 1 Actual: 1
# Predicted: 0 Actual: 0
# Predicted: 1 Actual: 1
# Predicted: 0 Actual: 0
# Predicted: 0 Actual: 0
# Predicted: 1 Actual: 1
# Predicted: 1 Actual: 1
# Predicted: 0 Actual: 0
# Predicted: 0 Actual: 0
# Predicted: 1 Actual: 1
# Predicted: 0 Actual: 0
# Predicted: 1 Actual: 1
# Predicted: 0 Actual: 0
# Predicted: 0 Actual: 0
# Predicted: 1 Actual: 1
# Predicted: 1 Actual: 1
# Predicted: 0 Actual: 0
# Predicted: 1 Actual: 1
# Predicted: 1 Actual: 1
# Predicted: 0 Actual: 0

# %%
modelNames = [
    '1d',
    '2d',
    '3d',
    '4d',
    '5d',
    '6d',
    '7d'
]

NODES_PER_HIDDEN_LAYER = 64

models = [ 

    keras.models.Sequential([
    keras.layers.Input(shape=(4394,)),
    keras.layers.Dense(2, activation='softmax')
]),

    keras.models.Sequential([
    keras.layers.Input(shape=(4394,)),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(2, activation='softmax')
]),

 keras.models.Sequential([
    keras.layers.Input(shape=(4394,)),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(2, activation='softmax')
]),

 keras.models.Sequential([
    keras.layers.Input(shape=(4394,)),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(2, activation='softmax')
]),

 keras.models.Sequential([
    keras.layers.Input(shape=(4394,)),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(2, activation='softmax')
]),

keras.models.Sequential([
    keras.layers.Input(shape=(4394,)),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(2, activation='softmax')
]),

keras.models.Sequential([
    keras.layers.Input(shape=(4394,)),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),
    keras.layers.Dense(2, activation='softmax')
])

]

# %%
LOSS_FN = keras.losses.sparse_categorical_crossentropy

for model in models:
    model.compile(optimizer='adam',loss=LOSS_FN,metrics=['accuracy'])

# %%
TRAINING_EPOCHS = 20

# train all models
for model, name in zip(models, modelNames):
    print(f'training model {name}')
    model.fit(X_train, y_train, epochs=TRAINING_EPOCHS)
# Out:
# training model 1d
# Epoch 1/20
# 2/2 [==============================] - 0s 4ms/step - loss: 10.7820 - accuracy: 0.5833
# Epoch 2/20
# 2/2 [==============================] - 0s 3ms/step - loss: 4.9582 - accuracy: 0.6833
# Epoch 3/20
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0284 - accuracy: 0.9000
# Epoch 4/20
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1827 - accuracy: 0.9833
# Epoch 5/20
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0903 - accuracy: 0.9833
# Epoch 6/20
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0199 - accuracy: 0.9833
# Epoch 7/20
# 2/2 [==============================] - 0s 0s/step - loss: 1.3589e-06 - accuracy: 1.0000
# Epoch 8/20
# 2/2 [==============================] - 0s 2ms/step - loss: 2.1556e-06 - accuracy: 1.0000
# Epoch 9/20
# 2/2 [==============================] - 0s 3ms/step - loss: 2.6602e-05 - accuracy: 1.0000
# Epoch 10/20
# 2/2 [==============================] - 0s 3ms/step - loss: 5.2146e-05 - accuracy: 1.0000
# Epoch 11/20
# 2/2 [==============================] - 0s 4ms/step - loss: 2.5767e-04 - accuracy: 1.0000
# Epoch 12/20
# 2/2 [==============================] - 0s 3ms/step - loss: 3.4179e-04 - accuracy: 1.0000
# Epoch 13/20
# 2/2 [==============================] - 0s 3ms/step - loss: 4.0448e-04 - accuracy: 1.0000
# Epoch 14/20
# 2/2 [==============================] - 0s 3ms/step - loss: 3.6300e-04 - accuracy: 1.0000
# Epoch 15/20
# 2/2 [==============================] - 0s 0s/step - loss: 2.8876e-04 - accuracy: 1.0000
# Epoch 16/20
# 2/2 [==============================] - 0s 10ms/step - loss: 2.9626e-04 - accuracy: 1.0000
# Epoch 17/20
# 2/2 [==============================] - 0s 2ms/step - loss: 2.9393e-04 - accuracy: 1.0000
# Epoch 18/20
# 2/2 [==============================] - 0s 2ms/step - loss: 2.2617e-04 - accuracy: 1.0000
# Epoch 19/20
# 2/2 [==============================] - 0s 4ms/step - loss: 1.5481e-04 - accuracy: 1.0000
# Epoch 20/20
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2184e-04 - accuracy: 1.0000
# training model 2d
# Epoch 1/20
# 2/2 [==============================] - 0s 5ms/step - loss: 12.5162 - accuracy: 0.5667
# Epoch 2/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5060 - accuracy: 0.9833
# Epoch 3/20
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8636 - accuracy: 0.9667
# Epoch 4/20
# 2/2 [==============================] - 0s 4ms/step - loss: 4.7101e-06 - accuracy: 1.0000
# Epoch 5/20
# 2/2 [==============================] - 0s 4ms/step - loss: 1.1921e-08 - accuracy: 1.0000
# Epoch 6/20
# 2/2 [==============================] - 0s 3ms/step - loss: 3.9736e-09 - accuracy: 1.0000
# Epoch 7/20
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9868e-09 - accuracy: 1.0000
# Epoch 8/20
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9868e-09 - accuracy: 1.0000
# Epoch 9/20
# 2/2 [==============================] - 0s 649us/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 10/20
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 11/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 12/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 13/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 14/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 15/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 16/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 17/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 18/20
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 19/20
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 20/20
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# training model 3d
# Epoch 1/20
# 2/2 [==============================] - 0s 6ms/step - loss: 9.0759 - accuracy: 0.5833
# Epoch 2/20
# 2/2 [==============================] - 0s 5ms/step - loss: 1.6379 - accuracy: 0.8667
# Epoch 3/20
# 2/2 [==============================] - 0s 4ms/step - loss: 1.6083 - accuracy: 0.8667
# Epoch 4/20
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 5/20
# 2/2 [==============================] - 0s 3ms/step - loss: 3.7551e-07 - accuracy: 1.0000
# Epoch 6/20
# 2/2 [==============================] - 0s 4ms/step - loss: 1.0918e-05 - accuracy: 1.0000
# Epoch 7/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 8/20
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 9/20
# 2/2 [==============================] - 0s 11ms/step - loss: 1.0811e-05 - accuracy: 1.0000
# Epoch 10/20
# 2/2 [==============================] - 0s 4ms/step - loss: 9.8941e-07 - accuracy: 1.0000
# Epoch 11/20
# 2/2 [==============================] - 0s 4ms/step - loss: 3.5961e-07 - accuracy: 1.0000
# Epoch 12/20
# 2/2 [==============================] - 0s 3ms/step - loss: 6.1591e-08 - accuracy: 1.0000
# Epoch 13/20
# 2/2 [==============================] - 0s 3ms/step - loss: 1.3908e-08 - accuracy: 1.0000
# Epoch 14/20
# 2/2 [==============================] - 0s 4ms/step - loss: 3.9736e-09 - accuracy: 1.0000
# Epoch 15/20
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9868e-09 - accuracy: 1.0000
# Epoch 16/20
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9868e-09 - accuracy: 1.0000
# Epoch 17/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 18/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 19/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 20/20
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# training model 4d
# Epoch 1/20
# 2/2 [==============================] - 0s 0s/step - loss: 4.7968 - accuracy: 0.6833
# Epoch 2/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6984 - accuracy: 0.8667
# Epoch 3/20
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5409 - accuracy: 0.9000
# Epoch 4/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 5/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0267 - accuracy: 0.9833
# Epoch 6/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 7/20
# 2/2 [==============================] - 0s 4ms/step - loss: 3.3496e-04 - accuracy: 1.0000
# Epoch 8/20
# 2/2 [==============================] - 0s 4ms/step - loss: 1.1068e-04 - accuracy: 1.0000
# Epoch 9/20
# 2/2 [==============================] - 0s 4ms/step - loss: 6.1876e-05 - accuracy: 1.0000
# Epoch 10/20
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1677e-05 - accuracy: 1.0000
# Epoch 11/20
# 2/2 [==============================] - 0s 3ms/step - loss: 5.0578e-06 - accuracy: 1.0000
# Epoch 12/20
# 2/2 [==============================] - 0s 4ms/step - loss: 2.4695e-06 - accuracy: 1.0000
# Epoch 13/20
# 2/2 [==============================] - 0s 0s/step - loss: 1.2914e-06 - accuracy: 1.0000
# Epoch 14/20
# 2/2 [==============================] - 0s 4ms/step - loss: 7.8081e-07 - accuracy: 1.0000
# Epoch 15/20
# 2/2 [==============================] - 0s 4ms/step - loss: 5.1259e-07 - accuracy: 1.0000
# Epoch 16/20
# 2/2 [==============================] - 0s 4ms/step - loss: 4.2915e-07 - accuracy: 1.0000
# Epoch 17/20
# 2/2 [==============================] - 0s 4ms/step - loss: 2.8610e-07 - accuracy: 1.0000
# Epoch 18/20
# 2/2 [==============================] - 0s 4ms/step - loss: 2.5233e-07 - accuracy: 1.0000
# Epoch 19/20
# 2/2 [==============================] - 0s 3ms/step - loss: 2.1656e-07 - accuracy: 1.0000
# Epoch 20/20
# 2/2 [==============================] - 0s 5ms/step - loss: 1.8477e-07 - accuracy: 1.0000
# training model 5d
# Epoch 1/20
# 2/2 [==============================] - 1s 5ms/step - loss: 4.0128 - accuracy: 0.6000
# Epoch 2/20
# 2/2 [==============================] - 0s 5ms/step - loss: 1.3232 - accuracy: 0.7667
# Epoch 3/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1586 - accuracy: 0.9333
# Epoch 4/20
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1383 - accuracy: 0.9667
# Epoch 5/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 6/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0615 - accuracy: 0.9833
# Epoch 7/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0227 - accuracy: 0.9833
# Epoch 8/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 9/20
# 2/2 [==============================] - 0s 4ms/step - loss: 7.2010e-04 - accuracy: 1.0000
# Epoch 10/20
# 2/2 [==============================] - 0s 5ms/step - loss: 5.8672e-04 - accuracy: 1.0000
# Epoch 11/20
# 2/2 [==============================] - 0s 5ms/step - loss: 6.6084e-04 - accuracy: 1.0000
# Epoch 12/20
# 2/2 [==============================] - 0s 4ms/step - loss: 6.5610e-04 - accuracy: 1.0000
# Epoch 13/20
# 2/2 [==============================] - 0s 3ms/step - loss: 7.0931e-04 - accuracy: 1.0000
# Epoch 14/20
# 2/2 [==============================] - 0s 4ms/step - loss: 6.7915e-04 - accuracy: 1.0000
# Epoch 15/20
# 2/2 [==============================] - 0s 4ms/step - loss: 5.4675e-04 - accuracy: 1.0000
# Epoch 16/20
# 2/2 [==============================] - 0s 5ms/step - loss: 4.2540e-04 - accuracy: 1.0000
# Epoch 17/20
# 2/2 [==============================] - 0s 4ms/step - loss: 2.8934e-04 - accuracy: 1.0000
# Epoch 18/20
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1637e-04 - accuracy: 1.0000
# Epoch 19/20
# 2/2 [==============================] - 0s 6ms/step - loss: 1.8244e-04 - accuracy: 1.0000
# Epoch 20/20
# 2/2 [==============================] - 0s 5ms/step - loss: 1.5677e-04 - accuracy: 1.0000
# training model 6d
# Epoch 1/20
# 2/2 [==============================] - 1s 17ms/step - loss: 4.4408 - accuracy: 0.5667
# Epoch 2/20
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5375 - accuracy: 0.8667
# Epoch 3/20
# 2/2 [==============================] - 0s 0s/step - loss: 0.1014 - accuracy: 0.9500
# Epoch 4/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 5/20
# 2/2 [==============================] - 0s 0s/step - loss: 0.0243 - accuracy: 0.9833
# Epoch 6/20
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 7/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 8/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 9/20
# 2/2 [==============================] - 0s 4ms/step - loss: 6.0916e-04 - accuracy: 1.0000
# Epoch 10/20
# 2/2 [==============================] - 0s 4ms/step - loss: 4.3272e-04 - accuracy: 1.0000
# Epoch 11/20
# 2/2 [==============================] - 0s 5ms/step - loss: 3.1355e-04 - accuracy: 1.0000
# Epoch 12/20
# 2/2 [==============================] - 0s 4ms/step - loss: 2.2431e-04 - accuracy: 1.0000
# Epoch 13/20
# 2/2 [==============================] - 0s 4ms/step - loss: 1.7424e-04 - accuracy: 1.0000
# Epoch 14/20
# 2/2 [==============================] - 0s 4ms/step - loss: 1.3441e-04 - accuracy: 1.0000
# Epoch 15/20
# 2/2 [==============================] - 0s 5ms/step - loss: 1.0361e-04 - accuracy: 1.0000
# Epoch 16/20
# 2/2 [==============================] - 0s 4ms/step - loss: 8.2838e-05 - accuracy: 1.0000
# Epoch 17/20
# 2/2 [==============================] - 0s 0s/step - loss: 6.7081e-05 - accuracy: 1.0000
# Epoch 18/20
# 2/2 [==============================] - 0s 5ms/step - loss: 5.6254e-05 - accuracy: 1.0000
# Epoch 19/20
# 2/2 [==============================] - 0s 4ms/step - loss: 4.9709e-05 - accuracy: 1.0000
# Epoch 20/20
# 2/2 [==============================] - 0s 2ms/step - loss: 4.3513e-05 - accuracy: 1.0000
# training model 7d
# Epoch 1/20
# 2/2 [==============================] - 1s 5ms/step - loss: 1.6079 - accuracy: 0.3667
# Epoch 2/20
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2676 - accuracy: 0.8667
# Epoch 3/20
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0715 - accuracy: 0.9833
# Epoch 4/20
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0432 - accuracy: 0.9833
# Epoch 5/20
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 6/20
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 7/20
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 8/20
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 9/20
# 2/2 [==============================] - 0s 5ms/step - loss: 8.4769e-04 - accuracy: 1.0000
# Epoch 10/20
# 2/2 [==============================] - 0s 4ms/step - loss: 7.4350e-04 - accuracy: 1.0000
# Epoch 11/20
# 2/2 [==============================] - 0s 5ms/step - loss: 5.5241e-04 - accuracy: 1.0000
# Epoch 12/20
# 2/2 [==============================] - 0s 5ms/step - loss: 3.7912e-04 - accuracy: 1.0000
# Epoch 13/20
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1416e-04 - accuracy: 1.0000
# Epoch 14/20
# 2/2 [==============================] - 0s 5ms/step - loss: 1.6081e-04 - accuracy: 1.0000
# Epoch 15/20
# 2/2 [==============================] - 0s 4ms/step - loss: 1.2030e-04 - accuracy: 1.0000
# Epoch 16/20
# 2/2 [==============================] - 0s 4ms/step - loss: 8.8908e-05 - accuracy: 1.0000
# Epoch 17/20
# 2/2 [==============================] - 0s 4ms/step - loss: 7.1987e-05 - accuracy: 1.0000
# Epoch 18/20
# 2/2 [==============================] - 0s 5ms/step - loss: 5.3814e-05 - accuracy: 1.0000
# Epoch 19/20
# 2/2 [==============================] - 0s 5ms/step - loss: 4.8825e-05 - accuracy: 1.0000
# Epoch 20/20
# 2/2 [==============================] - 0s 5ms/step - loss: 4.1634e-05 - accuracy: 1.0000

# %%
# get all model accuracy scores on test data
scores = [model.evaluate(X_test,y_test)[1] for model in models]
# Out:
# 1/1 [==============================] - 0s 90ms/step - loss: 8.9556 - accuracy: 0.8462
# 1/1 [==============================] - 0s 93ms/step - loss: 2.7266e-05 - accuracy: 1.0000
# 1/1 [==============================] - 0s 119ms/step - loss: 0.3254 - accuracy: 0.9615
# 1/1 [==============================] - 0s 101ms/step - loss: 1.3760 - accuracy: 0.9615
# 1/1 [==============================] - 0s 109ms/step - loss: 0.4515 - accuracy: 0.9231
# 1/1 [==============================] - 0s 109ms/step - loss: 0.2632 - accuracy: 0.9231
# 1/1 [==============================] - 0s 110ms/step - loss: 0.1686 - accuracy: 0.9231

# %%
import matplotlib.pyplot as plt
modelNames.insert(0, 'perceptron')
scores.insert(0, p.score(X_test, y_test) )

plt.bar(modelNames,scores)
plt.ylim(0.75, 1.0)
plt.ylabel('Test Accuracy (%)') 
plt.xlabel(str(NODES_PER_HIDDEN_LAYER) + " nodes per hidden layer")
plt.show()
